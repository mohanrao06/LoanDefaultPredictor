# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("../01_Data/02_Processed/final_features.csv",index_col=False)

# %%
df.head()
# Out:
#    Unnamed: 0  loan_amnt  term  int_rate  installment grade emp_length  \
# 0           0     3600.0    36     13.99   123.029999     C  10+ years
# 1           1    24700.0    36     11.99   820.280029     C  10+ years
# 2           2    20000.0    60     10.78   432.660004     B  10+ years
# 3           4    10400.0    60     22.45   289.910004     F    3 years
# 4           5    11950.0    36     13.44   405.179993     C    4 years
#
#   home_ownership  annual_inc verification_status  ... disbursement_method  \
# 0       MORTGAGE     55000.0        Not Verified  ...                Cash
# 1       MORTGAGE     65000.0        Not Verified  ...                Cash
# 2       MORTGAGE     63000.0        Not Verified  ...                Cash
# 3       MORTGAGE    104433.0     Source Verified  ...                Cash
# 4           RENT     34000.0     Source Verified  ...                Cash
#
#   debt_settlement_flag  loan_age_months  days_since_last_payment  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1382352 entries, 0 to 1382351
# Data columns (total 81 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   Unnamed: 0                   1382352 non-null  int64
#  1   loan_amnt                    1382352 non-null  float64
#  2   term                         1382352 non-null  int64
#  3   int_rate                     1382352 non-null  float64
#  4   installment                  1382352 non-null  float64
#  5   grade                        1382352 non-null  object
#  6   emp_length                   1382352 non-null  object
#  7   home_ownership               1382352 non-null  object
#  8   annual_inc                   1382352 non-null  float64
#  9   verification_status          1382352 non-null  object
#  10  loan_status                  1382352 non-null  object
#  11  purpose                      1382352 non-null  object
# ...

# %%
df.drop(columns='Unnamed: 0',inplace=True)
df.head()
# Out:
#    loan_amnt  term  int_rate  installment grade emp_length home_ownership  \
# 0     3600.0    36     13.99   123.029999     C  10+ years       MORTGAGE
# 1    24700.0    36     11.99   820.280029     C  10+ years       MORTGAGE
# 2    20000.0    60     10.78   432.660004     B  10+ years       MORTGAGE
# 3    10400.0    60     22.45   289.910004     F    3 years       MORTGAGE
# 4    11950.0    36     13.44   405.179993     C    4 years           RENT
#
#    annual_inc verification_status loan_status  ... disbursement_method  \
# 0     55000.0        Not Verified  Fully Paid  ...                Cash
# 1     65000.0        Not Verified  Fully Paid  ...                Cash
# 2     63000.0        Not Verified  Fully Paid  ...                Cash
# 3    104433.0     Source Verified  Fully Paid  ...                Cash
# 4     34000.0     Source Verified  Fully Paid  ...                Cash
#
#    debt_settlement_flag  loan_age_months  days_since_last_payment  \
# ...

# %%
df['loan_status_clean'].value_counts()
# Out:
# loan_status_clean
# 0    1078740
# 1     303612
# Name: count, dtype: int64

# %%
sns.barplot(df['loan_status_clean'].value_counts())
# Out:
# <Axes: xlabel='loan_status_clean', ylabel='count'>

# %%
df['term'].value_counts()
# Out:
# term
# 36    1043060
# 60     339292
# Name: count, dtype: int64

# %%
df['emp_length'].value_counts()
# Out:
# emp_length
# 10+ years    534719
# 2 years      125246
# < 1 year     111768
# 3 years      110684
# 1 year        91130
# 5 years       86452
# 4 years       82975
# 6 years       64377
# 8 years       62043
# 7 years       60927
# 9 years       52031
# Name: count, dtype: int64

# %%
emp_length_mapping = {
    '< 1 year': 0,
    '1 year': 1,
    '2 years': 2,
    '3 years': 3,
    '4 years': 4,
    '5 years': 5,
    '6 years': 6,
    '7 years': 7,
    '8 years': 8,
    '9 years': 9,
    '10+ years': 10
}
df['emp_length'] = df['emp_length'].replace(emp_length_mapping)
# Out:
# C:\Users\gedal\AppData\Local\Temp\ipykernel_12708\1055342275.py:14: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['emp_length'] = df['emp_length'].replace(emp_length_mapping)

# %%
df['emp_length'].value_counts()
# Out:
# emp_length
# 10    534719
# 2     125246
# 0     111768
# 3     110684
# 1      91130
# 5      86452
# 4      82975
# 6      64377
# 8      62043
# 7      60927
# 9      52031
# Name: count, dtype: int64

# %%
df['grade'].value_counts()
# Out:
# grade
# B    400655
# C    394346
# A    237488
# D    209286
# E     97559
# F     33315
# G      9703
# Name: count, dtype: int64

# %%
grade_mapping = {
    'G': 0,
    'F': 1,
    'E': 2,
    'D': 3,
    'C': 4,
    'B': 5,
    'A': 6
}
df['grade'] = df['grade'].replace(grade_mapping)
# Out:
# C:\Users\gedal\AppData\Local\Temp\ipykernel_12708\1608773698.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['grade'] = df['grade'].replace(grade_mapping)

# %%
df['grade'].value_counts()
# Out:
# grade
# 5    400655
# 4    394346
# 6    237488
# 3    209286
# 2     97559
# 1     33315
# 0      9703
# Name: count, dtype: int64

# %%
df['home_ownership'].value_counts()
# Out:
# home_ownership
# MORTGAGE    682143
# RENT        550448
# OWN         149215
# ANY            311
# OTHER          182
# NONE            53
# Name: count, dtype: int64

# %%
replace_cols=['ANY','OTHER','NONE']
df['home_ownership']=df['home_ownership'].replace(replace_cols,'OTHER')

# %%
df['home_ownership'].value_counts()
# Out:
# home_ownership
# MORTGAGE    682143
# RENT        550448
# OWN         149215
# OTHER          546
# Name: count, dtype: int64

# %%
one_hot_cols = [
    'home_ownership',
    'purpose',
    'verification_status',
    'initial_list_status',
    'application_type',
    'disbursement_method',
    'debt_settlement_flag',
]

# %%
df['purpose'].value_counts()
# Out:
# purpose
# debt_consolidation    801438
# credit_card           302131
# home_improvement       90045
# other                  80785
# major_purchase         30413
# small_business         16098
# medical                16063
# car                    14949
# moving                  9806
# vacation                9308
# house                   7588
# wedding                 2350
# renewable_energy         955
# educational              423
# Name: count, dtype: int64

# %%
df['verification_status'].value_counts()
# Out:
# verification_status
# Source Verified    536032
# Verified           429617
# Not Verified       416703
# Name: count, dtype: int64

# %%
df['initial_list_status'].value_counts()
# Out:
# initial_list_status
# w    810886
# f    571466
# Name: count, dtype: int64

# %%
df['application_type'].value_counts()
# Out:
# application_type
# Individual    1352768
# Joint App       29584
# Name: count, dtype: int64

# %%
df['disbursement_method'].value_counts()
# Out:
# disbursement_method
# Cash         1374461
# DirectPay       7891
# Name: count, dtype: int64

# %%
df['debt_settlement_flag'].value_counts()
# Out:
# debt_settlement_flag
# N    1348134
# Y      34218
# Name: count, dtype: int64

# %%
df = pd.get_dummies(df, columns=one_hot_cols, drop_first=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1382352 entries, 0 to 1382351
# Data columns (total 95 columns):
#  #   Column                               Non-Null Count    Dtype
# ---  ------                               --------------    -----
#  0   loan_amnt                            1382352 non-null  float64
#  1   term                                 1382352 non-null  int64
#  2   int_rate                             1382352 non-null  float64
#  3   installment                          1382352 non-null  float64
#  4   grade                                1382352 non-null  int64
#  5   emp_length                           1382352 non-null  int64
#  6   annual_inc                           1382352 non-null  float64
#  7   loan_status                          1382352 non-null  object
#  8   addr_state                           1382352 non-null  float64
#  9   dti                                  1382352 non-null  float64
# ...

# %%
cluster_features = [
    'int_rate',
    'dti',
    'loan_amnt',
    'annual_inc',
    'credit_history_length'
]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(df[cluster_features])

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

inertia = []
for k in range(2, 8):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

plt.plot(range(2, 8), inertia, marker='o')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method')
plt.show()
# Out:
# C:\Users\gedal\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\gedal\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#         "wmic CPU Get NumberOfCores /Format:csv".split(),
#         capture_output=True,
#         text=True,
#     )
#   File "C:\Users\gedal\anaconda3\Lib\subprocess.py", line 554, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gedal\anaconda3\Lib\subprocess.py", line 1039, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
# ...

# %%
k = 4  # or the number you decided
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
df['Cluster_ID'] = kmeans.labels_

# %%
df['Cluster_ID'].value_counts()
# Out:
# Cluster_ID
# 2    482640
# 0    365735
# 3    288942
# 1    245035
# Name: count, dtype: int64

# %%
# Add scaled features back to dataframe temporarily
df_clusters = df[cluster_features + ['Cluster_ID']]

# Check average values per cluster
cluster_summary = df_clusters.groupby('Cluster_ID').mean()
print(cluster_summary)
# Out:
#              int_rate        dti     loan_amnt     annual_inc  \
# Cluster_ID
# 0           17.095700  26.043561  13738.536304   53744.185740
# 1           11.281845  19.303841  12422.263860   68661.368524
# 2           11.405836  13.421260   9517.657985   59820.309609
# 3           13.191406  15.211922  25387.278416  121238.314294
#
#             credit_history_length
# Cluster_ID
# 0                      203.814850
# 1                      360.700684
# 2                      190.750885
# 3                      258.172249

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1382352 entries, 0 to 1382351
# Data columns (total 96 columns):
#  #   Column                               Non-Null Count    Dtype
# ---  ------                               --------------    -----
#  0   loan_amnt                            1382352 non-null  float64
#  1   term                                 1382352 non-null  int64
#  2   int_rate                             1382352 non-null  float64
#  3   installment                          1382352 non-null  float64
#  4   grade                                1382352 non-null  int64
#  5   emp_length                           1382352 non-null  int64
#  6   annual_inc                           1382352 non-null  float64
#  7   loan_status                          1382352 non-null  object
#  8   addr_state                           1382352 non-null  float64
#  9   dti                                  1382352 non-null  float64
# ...

# %%
numeric_cols = [
    'loan_amnt', 'term', 'int_rate', 'installment', 'grade', 'emp_length', 'annual_inc', 
    'addr_state', 'dti', 'fico_range_low', 'fico_range_high', 'inq_last_6mths', 'open_acc', 
    'revol_bal', 'revol_util', 'total_acc', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 
    'total_rec_int', 'last_pymnt_amnt', 'last_fico_range_high', 'last_fico_range_low', 
    'tot_cur_bal', 'open_acc_6m', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 
    'total_bal_il', 'il_util', 'open_rv_24m', 'max_bal_bc', 'all_util', 'total_rev_hi_lim', 
    'inq_fi', 'total_cu_tl', 'inq_last_12m', 'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 
    'bc_util', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 
    'mo_sin_rcnt_tl', 'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_inq', 'num_actv_bc_tl', 
    'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 
    'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 
    'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit', 
    'loan_age_months', 'days_since_last_payment', 'days_since_last_credit_pull', 
    'credit_history_length', 'days_since_last_payment_log', 'loan_to_income_ratio', 
    'installment_to_income_ratio'
]

# %%
# Fill missing numeric values with median
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# %%
import numpy as np

# Replace inf/-inf with NaN first
df[numeric_cols] = df[numeric_cols].replace([np.inf, -np.inf], np.nan)

# Fill resulting NaNs again
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# %%
df[numeric_cols].head()
# Out:
#    loan_amnt      term  int_rate  installment     grade  emp_length  \
# 0  -1.245921 -0.570338  0.155387    -1.233488 -0.185442    1.026547
# 1   1.173374 -0.570338 -0.271778     1.508627 -0.185442    1.026547
# 2   0.634479  1.753347 -0.530212    -0.015788  0.585594    1.026547
# 3  -0.466243  1.753347  1.962291    -0.577190 -2.498549   -0.861519
# 4  -0.288523 -0.570338  0.037916    -0.123861 -0.185442   -0.591795
#
#    annual_inc  addr_state       dti  fico_range_low  ...  total_bal_ex_mort  \
# 0   -0.489653    0.402136 -1.436273       -0.683681  ...          -1.159821
# 1   -0.211719    0.407872 -0.247948        0.653155  ...          -0.193048
# 2   -0.267306   -0.941560 -0.866111       -0.015263  ...          -0.826177
# 3    0.884258    0.402136  0.842033       -0.015263  ...           1.522183
# 4   -1.073314   -0.701389 -0.934015       -0.182367  ...          -1.005888
#
#    total_bc_limit  total_il_high_credit_limit  loan_age_months  \
# ...

# %%
df[numeric_cols].agg(['mean','std'])
# Out:
#          loan_amnt          term      int_rate   installment         grade  \
# mean  2.158842e-18  2.294129e-16  1.304845e-15 -3.445923e-17  3.119424e-16
# std   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#         emp_length    annual_inc    addr_state           dti  fico_range_low  \
# mean  9.108643e-17 -1.709638e-15 -3.992624e-15  3.688536e-17    1.417269e-15
# std   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00    1.000000e+00
#
#       ...  total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# mean  ...      -5.855602e-17   -4.124416e-17                5.526635e-17
# std   ...       1.000000e+00    1.000000e+00                1.000000e+00
#
#       loan_age_months  days_since_last_payment  days_since_last_credit_pull  \
# mean     3.309196e-17             5.724015e-17                 6.743811e-17
# std      1.000000e+00             1.000000e+00                 1.000000e+00
#
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(df['annual_inc'], bins=50)
plt.title('Scaled annual_inc distribution')
plt.show()

# %%
from sklearn.decomposition import PCA

# Assuming 'numeric_cols' are your scaled numeric columns
X_scaled = df[numeric_cols]

# Initialize PCA to retain 95% variance
pca = PCA(n_components=0.95, random_state=42)

# Fit and transform
X_pca = pca.fit_transform(X_scaled)

# Check explained variance
print(f"Original shape: {X_scaled.shape}")
print(f"Transformed shape: {X_pca.shape}")
print(f"Explained variance ratio: {sum(pca.explained_variance_ratio_):.2f}")
# Out:
# Original shape: (1382352, 71)
# Transformed shape: (1382352, 38)
# Explained variance ratio: 0.95

# %%
sample_df = X_pca[np.random.choice(X_pca.shape[0], 50000, replace=False)]

# %%
from sklearn.cluster import MiniBatchKMeans

kmeans = MiniBatchKMeans(n_clusters=5, batch_size=10000, random_state=42)
kmeans.fit(X_pca)
df['Cluster_PCA'] = kmeans.labels_

# %%
# Count of borrowers in each cluster
print(df['Cluster_PCA'].value_counts())

# Optionally check cluster means of original features
cluster_summary = df.groupby('Cluster_PCA')[numeric_cols].mean()
print(cluster_summary)
# Out:
# Cluster_PCA
# 4    458975
# 0    276265
# 2    250255
# 1    214996
# 3    181861
# Name: count, dtype: int64
#              loan_amnt      term  int_rate  installment     grade  emp_length  \
# Cluster_PCA
# 0             1.005202  0.572273  0.396950     0.948681 -0.397282    0.102572
# 1            -0.193499 -0.236867 -0.943021    -0.231535  0.921291    0.007759
# 2            -0.371794 -0.040585  0.372577    -0.329458 -0.353443   -0.000475
# 3             0.779309  0.152472 -0.213580     0.744506  0.203822    0.214134
# 4            -0.620476 -0.271791  0.084285    -0.577932 -0.080473   -0.149963
#
#              annual_inc  addr_state       dti  fico_range_low  ...  \
# Cluster_PCA                                                    ...
# 0              0.398580   -0.051209  0.110281       -0.163755  ...
# 1              0.068527   -0.036194 -0.418328        1.325406  ...
# 2             -0.106148    0.055415  0.331252       -0.410262  ...
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(X_pca[:,0], X_pca[:,1], c=df['Cluster_PCA'], cmap='viridis', s=1)
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.title('Borrower Segmentation')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1382352 entries, 0 to 1382351
# Data columns (total 97 columns):
#  #   Column                               Non-Null Count    Dtype
# ---  ------                               --------------    -----
#  0   loan_amnt                            1382352 non-null  float64
#  1   term                                 1382352 non-null  float64
#  2   int_rate                             1382352 non-null  float64
#  3   installment                          1382352 non-null  float64
#  4   grade                                1382352 non-null  float64
#  5   emp_length                           1382352 non-null  float64
#  6   annual_inc                           1382352 non-null  float64
#  7   loan_status                          1382352 non-null  object
#  8   addr_state                           1382352 non-null  float64
#  9   dti                                  1382352 non-null  float64
# ...

# %%
df.drop(columns='loan_status')
# Out:
#          loan_amnt      term  int_rate  installment     grade  emp_length  \
# 0        -1.245921 -0.570338  0.155387    -1.233488 -0.185442    1.026547
# 1         1.173374 -0.570338 -0.271778     1.508627 -0.185442    1.026547
# 2         0.634479  1.753347 -0.530212    -0.015788  0.585594    1.026547
# 3        -0.466243  1.753347  1.962291    -0.577190 -2.498549   -0.861519
# 4        -0.288523 -0.570338  0.037916    -0.123861 -0.185442   -0.591795
# ...            ...       ...       ...          ...       ...         ...
# 1382347   0.405162  1.753347 -0.805733    -0.230950  0.585594   -0.322072
# 1382348   1.712269  1.753347  0.155387     0.972435 -0.185442    0.756824
# 1382349   2.010381  1.753347  0.262178     1.243009 -0.185442   -0.861519
# 1382350   0.175845  1.753347 -0.100912    -0.292340 -0.185442    1.026547
# 1382351   1.093113  1.753347  0.262178     0.502942 -0.185442   -0.052348
#
#          annual_inc  addr_state       dti  fico_range_low  ...  \
# ...

# %%
import pandas as pd

# PCA DataFrame
pca_cols = [f'PCA_{i+1}' for i in range(X_pca.shape[1])]
df_pca = pd.DataFrame(X_pca, columns=pca_cols)

# Combine with categorical features and target
final_df = pd.concat([
    df_pca,
    df[[col for col in df.columns if df[col].dtype == 'bool']], 
    df['loan_status_clean'],
    df['Cluster_PCA']
], axis=1)

# %%
final_df.head()
# Out:
#       PCA_1     PCA_2     PCA_3     PCA_4     PCA_5     PCA_6     PCA_7  \
# 0 -4.198891  3.069744 -1.313620  0.514583  0.460915  3.194547 -0.689376
# 1  6.536175  0.318942 -2.781623 -2.889379  2.565126  0.941717  0.717540
# 2 -1.779451 -3.692088  0.393383  2.320619  0.970601  0.574678 -1.301291
# 3  3.296272  2.641588  2.767092  4.138526 -0.891985  1.712808  1.993473
# 4 -4.992690 -5.029717  0.832312 -2.035299 -1.045730 -0.110398 -1.032691
#
#       PCA_8     PCA_9    PCA_10  ...  purpose_vacation  purpose_wedding  \
# 0 -3.765832 -0.276543  2.396179  ...             False            False
# 1 -0.617313 -1.145367  0.681128  ...             False            False
# 2 -0.800435  0.379164 -0.138673  ...             False            False
# 3 -0.470656 -0.561543 -1.310988  ...             False            False
# 4  1.902685  0.853102 -0.956639  ...             False            False
#
#    verification_status_Source Verified  verification_status_Verified  \
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1382352 entries, 0 to 1382351
# Data columns (total 62 columns):
#  #   Column                               Non-Null Count    Dtype
# ---  ------                               --------------    -----
#  0   PCA_1                                1382352 non-null  float64
#  1   PCA_2                                1382352 non-null  float64
#  2   PCA_3                                1382352 non-null  float64
#  3   PCA_4                                1382352 non-null  float64
#  4   PCA_5                                1382352 non-null  float64
#  5   PCA_6                                1382352 non-null  float64
#  6   PCA_7                                1382352 non-null  float64
#  7   PCA_8                                1382352 non-null  float64
#  8   PCA_9                                1382352 non-null  float64
#  9   PCA_10                               1382352 non-null  float64
# ...

# %%
final_df.to_csv('../01_Data/02_Processed/final_data_processed.csv')
df.to_csv('../01_Data/02_Processed/final_cleaned_data.csv')
